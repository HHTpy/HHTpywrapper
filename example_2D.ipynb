# %% [markdown]
# ## 2-D example: Lena image

# %%
from pymatbridge import Matlab
import hht_plots

# %%
mlab = Matlab()
mlab.start()
mlab.run_code('addpaths')
# Out:
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-bf6d77d3-18c0-4bb7-ad3b-5821ed9a7f07
# Send 'exit' command to kill the server
# ..........MATLAB started and connected!
# {'content': {'datadir': '/tmp/MatlabData/', 'figures': [], 'stdout': ''},
#  'result': [],
#  'success': True}

# %%
filename = './Input_data/example_lena.png'
npixs = 512
Nstd = 0.4
NE = 20
seedNo = 1
numImf = 6
runCEEMD = 1
maxSift = 10
typeSpline = 2
toModifyBC = 1
randType = 2
checksignal = 1

# %%
res = mlab.run_func('meemd', filename, npixs, Nstd, NE, numImf, runCEEMD,
                    maxSift, typeSpline, toModifyBC, randType, seedNo,
                    checksignal)
imfs = res['result']

# %%
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
hht_plots.example_lena(filename, imfs)

mlab.stop()
# Out:
# <img src="data:image/png;base64,...">
# MATLAB closed
# True
